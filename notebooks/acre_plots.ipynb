# %%
SHOGGOTH_IDS = [
    "w4tt1jsu",
    "zfl5u3fd",
    "1sde8jph",
    "8fgq0wro",
    "w3euhlb8",
    ]

NO_PENALTY_IDS = [
    "9f3aqg2s",
    "x4ycjhu3",
    "tp2lfh4y",
    "1acq8chp",
    "put7hoex",
    "w6gsb6ok",
    "ip9tix4l",
    "5n394zv2",
]

PENALTY_IDS = [
    "zmhndno2",
    "sz2dldwu",
    "knaehdyp",
    "tty1nb3s",
    "z5f8wxgt",
    "eckpvxsz",
    "a11zhjue",
    "9wyk1cnx",
]

# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize wandb API
api = wandb.Api()

# Project configuration
project_name = "qwen3-reinforce-reasongym"
entity = None  # Set this to your wandb entity if needed

# Construct project path
project_path = f"{entity}/{project_name}" if entity else project_name

print(f"Loading runs from project: {project_path}")

# Get all runs from the project
runs = api.runs(project_path)

print(f"Found {len(runs)} total runs in the project")

# Filter for acre-related runs (based on the config patterns)
acre_runs = []
for run in runs:
    if run.name and ("acre" in run.name.lower() or "acre_shoggoth" in run.name.lower()):
        acre_runs.append(run)

print(f"Found {len(acre_runs)} acre-related runs:")
for run in acre_runs:
    print(f"  - {run.name} (state: {run.state}, created: {run.created_at})")
# Out:
# Loading runs from project: qwen3-reinforce-reasongym
# Found 183 total runs in the project
# Found 150 acre-related runs:
#   - acre-1 (state: killed, created: 2025-07-09T01:08:28Z)
#   - acre-2 (state: killed, created: 2025-07-09T01:09:49Z)
#   - acre-3 (state: killed, created: 2025-07-09T04:34:46Z)
#   - acre-4 (state: killed, created: 2025-07-11T21:00:27Z)
#   - acre-5 (state: failed, created: 2025-07-11T21:12:23Z)
#   - acre-6 (state: failed, created: 2025-07-11T21:25:44Z)
#   - acre-7 (state: killed, created: 2025-07-11T21:40:53Z)
#   - acre-8 (state: killed, created: 2025-07-11T22:45:12Z)
#   - acre-9 (state: killed, created: 2025-07-11T22:52:48Z)
#   - acre-10 (state: killed, created: 2025-07-11T23:03:11Z)
#   - acre-11 (state: killed, created: 2025-07-12T00:04:56Z)
#   - acre-12 (state: killed, created: 2025-07-12T00:29:43Z)
#   - acre-13 (state: killed, created: 2025-07-12T00:40:40Z)
#   - acre face shoggoth (state: killed, created: 2025-07-12T02:14:47Z)
#   - acre face shog short (state: finished, created: 2025-07-12T02:24:45Z)
#   - acre-15 (state: failed, created: 2025-07-12T04:42:56Z)
#   - acre face shog long (state: failed, created: 2025-07-12T05:15:52Z)
#   - acre-16 (state: killed, created: 2025-07-12T17:13:06Z)
#   - acre_shoggoth-1 (state: failed, created: 2025-07-12T17:26:01Z)
#   - acre_shoggoth-2 (state: failed, created: 2025-07-12T17:28:10Z)
#   - acre_shoggoth-3 (state: failed, created: 2025-07-12T17:30:10Z)
#   - acre_shoggoth-4 (state: killed, created: 2025-07-12T17:31:23Z)
#   - acre-17 (state: failed, created: 2025-07-12T17:33:31Z)
#   - acre-18 (state: failed, created: 2025-07-12T17:49:04Z)
#   - acre-19 (state: finished, created: 2025-07-12T18:12:17Z)
#   - acre_shoggoth-5 (state: crashed, created: 2025-07-12T20:52:23Z)
#   - acre-20 (state: killed, created: 2025-07-12T21:43:24Z)
#   - acre_shoggoth-6 (state: killed, created: 2025-07-12T22:05:49Z)
#   - acre-21 (state: killed, created: 2025-07-12T22:06:03Z)
#   - acre-22 (state: killed, created: 2025-07-12T22:20:11Z)
#   - acre_shoggoth-7 (state: failed, created: 2025-07-12T22:20:24Z)
#   - acre_shoggoth-8 (state: killed, created: 2025-07-13T00:10:53Z)
#   - acre-23 (state: finished, created: 2025-07-13T00:37:20Z)
#   - acre_shoggoth-9 (state: finished, created: 2025-07-13T00:37:26Z)
#   - acre-24 (state: finished, created: 2025-07-13T05:02:29Z)
#   - acre_shoggoth-10 (state: crashed, created: 2025-07-13T05:30:58Z)
#   - acre_shoggoth-11 (state: killed, created: 2025-07-13T09:45:36Z)
#   - acre_shoggoth-12 (state: finished, created: 2025-07-13T09:49:37Z)
#   - acre-25 (state: finished, created: 2025-07-13T09:51:12Z)
#   - acre-26 (state: finished, created: 2025-07-13T13:10:22Z)
#   - acre_shoggoth-13 (state: finished, created: 2025-07-13T13:38:48Z)
#   - acre_shoggoth-14 (state: crashed, created: 2025-07-13T18:23:36Z)
#   - acre-27 (state: crashed, created: 2025-07-13T18:27:13Z)
#   - acre-28 (state: finished, created: 2025-07-13T18:52:53Z)
#   - acre-29 (state: finished, created: 2025-07-13T18:55:36Z)
#   - acre_shoggoth-15 (state: crashed, created: 2025-07-13T18:58:23Z)
#   - acre-30 (state: crashed, created: 2025-07-13T18:58:26Z)
#   - acre-31 (state: crashed, created: 2025-07-13T18:58:46Z)
#   - acre-32 (state: crashed, created: 2025-07-13T19:04:04Z)
#   - acre_shoggoth-1e-4 (state: crashed, created: 2025-07-13T20:56:03Z)
#   - acre-1e-4 (state: crashed, created: 2025-07-13T20:57:08Z)
#   - acre-33 (state: finished, created: 2025-07-13T21:02:40Z)
#   - acre_shoggoth-16 (state: finished, created: 2025-07-13T21:03:17Z)
#   - acre_shoggoth-18 (state: finished, created: 2025-07-14T03:16:40Z)
#   - acre-35 (state: finished, created: 2025-07-14T03:17:38Z)
#   - acre_shoggoth-19 (state: finished, created: 2025-07-14T06:49:17Z)
#   - acre-36 (state: finished, created: 2025-07-14T06:59:01Z)
#   - acre-37 (state: finished, created: 2025-07-14T10:37:49Z)
#   - acre_shoggoth-20 (state: finished, created: 2025-07-14T10:54:25Z)
#   - acre-38 (state: finished, created: 2025-07-14T14:33:35Z)
#   - acre_shoggoth-21 (state: finished, created: 2025-07-14T14:52:57Z)
#   - acre_shoggoth-22 (state: crashed, created: 2025-07-14T18:51:23Z)
#   - acre-39 (state: failed, created: 2025-07-14T20:38:19Z)
#   - acre-40 (state: killed, created: 2025-07-14T20:39:20Z)
#   - acre old commit (state: killed, created: 2025-07-14T20:53:42Z)
#   - acre 0.5 2 (state: killed, created: 2025-07-14T20:55:27Z)
#   - acre 1 4 (state: killed, created: 2025-07-14T21:51:32Z)
#   - acre 1 4 1e-4 (state: killed, created: 2025-07-14T22:22:09Z)
#   - acre think200 max300 (state: killed, created: 2025-07-14T22:30:30Z)
#   - acre think300 max400 (state: killed, created: 2025-07-14T22:32:19Z)
#   - acre think200 minout100 max500 (state: killed, created: 2025-07-14T22:33:46Z)
#   - acre-41 (state: killed, created: 2025-07-15T00:07:15Z)
#   - acre-42 (state: killed, created: 2025-07-15T01:21:47Z)
#   - acre-43 (state: killed, created: 2025-07-15T01:22:10Z)
#   - acre-44 (state: killed, created: 2025-07-15T01:22:30Z)
#   - acre-45 (state: killed, created: 2025-07-15T01:38:24Z)
#   - acre-46 (state: killed, created: 2025-07-15T01:38:45Z)
#   - acre-47 (state: killed, created: 2025-07-15T01:38:59Z)
#   - acre-48 (state: killed, created: 2025-07-15T01:57:41Z)
#   - acre-49 (state: killed, created: 2025-07-15T01:58:01Z)
#   - acre-50 (state: killed, created: 2025-07-15T01:58:16Z)
#   - acre-51 (state: killed, created: 2025-07-15T02:14:59Z)
#   - acre-52 (state: killed, created: 2025-07-15T02:15:21Z)
#   - acre-53 (state: killed, created: 2025-07-15T02:15:57Z)
#   - acre_shoggoth-23 (state: killed, created: 2025-07-15T03:02:20Z)
#   - acre_shoggoth-24 (state: killed, created: 2025-07-15T03:04:27Z)
#   - acre_shoggoth-25 (state: killed, created: 2025-07-15T03:04:41Z)
#   - acre-54 nopen (state: finished, created: 2025-07-15T03:44:23Z)
#   - acre-55 nopen (state: finished, created: 2025-07-15T03:44:40Z)
#   - acre-54 nopen (state: finished, created: 2025-07-15T03:48:31Z)
#   - acre_shoggoth-26 (state: finished, created: 2025-07-15T05:12:44Z)
#   - acre-54 (state: finished, created: 2025-07-15T05:13:28Z)
#   - acre_no_penalty-1 (state: finished, created: 2025-07-15T05:15:14Z)
#   - acre_no_penalty-2 (state: finished, created: 2025-07-15T05:40:46Z)
#   - acre_shoggoth-27 (state: finished, created: 2025-07-15T05:41:09Z)
#   - acre-55 (state: finished, created: 2025-07-15T05:43:55Z)
#   - acre_no_penalty-3 (state: finished, created: 2025-07-15T06:05:55Z)
#   - acre_shoggoth-28 (state: finished, created: 2025-07-15T06:10:04Z)
#   - acre-56 (state: finished, created: 2025-07-15T06:12:46Z)
#   - acre_no_penalty-4 (state: finished, created: 2025-07-15T06:29:02Z)
#   - acre_shoggoth-29 (state: finished, created: 2025-07-15T06:38:37Z)
#   - acre-57 (state: finished, created: 2025-07-15T06:41:45Z)
#   - acre_no_penalty-5 (state: finished, created: 2025-07-15T06:55:10Z)
#   - acre_shoggoth-30 (state: finished, created: 2025-07-15T07:07:08Z)
#   - acre-58 (state: finished, created: 2025-07-15T07:11:55Z)
#   - acre_no_penalty-6 (state: finished, created: 2025-07-15T07:21:50Z)
#   - acre_shoggoth-31 (state: finished, created: 2025-07-15T07:36:24Z)
#   - acre-59 (state: finished, created: 2025-07-15T07:40:37Z)
#   - acre_no_penalty-7 (state: finished, created: 2025-07-15T07:47:02Z)
#   - acre_shoggoth-32 (state: crashed, created: 2025-07-15T08:06:51Z)
#   - acre-60 (state: crashed, created: 2025-07-15T08:11:30Z)
#   - acre_no_penalty-8 (state: crashed, created: 2025-07-15T08:13:46Z)
#   - acre_shoggoth-33 (state: crashed, created: 2025-07-15T08:33:04Z)
#   - acre-61 (state: crashed, created: 2025-07-15T08:33:36Z)
#   - acre_no_penalty-9 (state: crashed, created: 2025-07-15T08:34:17Z)
#   - acre_shoggoth-34 (state: crashed, created: 2025-07-15T09:21:52Z)
#   - acre-62 (state: crashed, created: 2025-07-15T09:23:19Z)
#   - acre_no_penalty-10 (state: crashed, created: 2025-07-15T09:24:01Z)
#   - acre_shoggoth-35 (state: crashed, created: 2025-07-15T09:37:07Z)
#   - acre_shoggoth-36 (state: finished, created: 2025-07-15T09:38:34Z)
#   - acre_no_penalty-11 (state: finished, created: 2025-07-15T09:39:09Z)
#   - acre-63 (state: finished, created: 2025-07-15T09:43:08Z)
#   - acre_shoggoth-37 (state: finished, created: 2025-07-15T10:29:34Z)
#   - acre_no_penalty-12 (state: finished, created: 2025-07-15T10:32:42Z)
#   - acre-64 (state: finished, created: 2025-07-15T10:41:10Z)
#   - acre_shoggoth-38 (state: finished, created: 2025-07-15T11:25:34Z)
#   - acre_no_penalty-13 (state: finished, created: 2025-07-15T11:25:40Z)
#   - acre-65 (state: finished, created: 2025-07-15T11:39:00Z)
#   - acre_no_penalty-14 (state: finished, created: 2025-07-15T12:18:53Z)
#   - acre_shoggoth-39 (state: finished, created: 2025-07-15T12:21:09Z)
#   - acre-66 (state: finished, created: 2025-07-15T12:36:44Z)
#   - acre_no_penalty-15 (state: finished, created: 2025-07-15T13:11:28Z)
#   - acre_shoggoth-40 (state: finished, created: 2025-07-15T13:17:09Z)
#   - acre-67 (state: finished, created: 2025-07-15T13:34:54Z)
#   - acre_no_penalty-16 (state: finished, created: 2025-07-15T14:01:48Z)
#   - acre_shoggoth-41 (state: finished, created: 2025-07-15T14:08:52Z)
#   - acre-68 (state: finished, created: 2025-07-15T14:36:08Z)
#   - acre_no_penalty-17 (state: finished, created: 2025-07-15T14:55:02Z)
#   - acre_shoggoth-42 (state: finished, created: 2025-07-15T15:02:08Z)
#   - acre-69 (state: finished, created: 2025-07-15T15:38:02Z)
#   - acre_no_penalty-18 (state: finished, created: 2025-07-15T15:44:01Z)
#   - acre_shoggoth-43 (state: finished, created: 2025-07-15T15:57:22Z)
#   - acre_no_penalty-19 (state: crashed, created: 2025-07-15T16:34:00Z)
#   - acre-70 (state: finished, created: 2025-07-15T16:35:47Z)
#   - acre_shoggoth-44 (state: crashed, created: 2025-07-15T16:52:43Z)
#   - acre_shoggoth-45 (state: finished, created: 2025-07-15T17:10:45Z)
#   - acre_shoggoth-46 (state: finished, created: 2025-07-15T17:15:45Z)
#   - acre-71 (state: running, created: 2025-07-15T17:37:00Z)
#   - acre_shoggoth-47 (state: running, created: 2025-07-15T18:03:43Z)
#   - acre_shoggoth-48 (state: running, created: 2025-07-15T18:04:43Z)

# %%
# Load detailed data for each acre run
run_data = []

for run in acre_runs:
    print(f"\nLoading data for run: {run.name}")
    
    # Get run configuration
    config = run.config
    
    # Get run summary (final metrics)
    summary = run.summary
    
    # Get run history (all logged metrics over time)
    history = run.history()
    
    # Store run information
    run_info = {
        'run': run,
        'name': run.name,
        'id': run.id,
        'state': run.state,
        'config': config,
        'summary': summary,
        'history': history
    }
    
    run_data.append(run_info)
    
    print(f"  - Config keys: {list(config.keys())}")
    print(f"  - Summary keys: {list(summary.keys())}")
    print(f"  - History shape: {history.shape}")
    print(f"  - History columns: {list(history.columns)}")

print(f"\nLoaded data for {len(run_data)} acre runs")

# %%
# Example: Plot training curves for all acre runs
plt.figure(figsize=(15, 10))

# Plot reward progression for each run
plt.subplot(2, 2, 1)
for run_info in run_data:
    history = run_info['history']
    if 'reward_mean' in history.columns:
        plt.plot(history['reward_mean'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Reward Mean')
plt.title('Training Reward Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot loss progression
plt.subplot(2, 2, 2)
for run_info in run_data:
    history = run_info['history']
    if 'loss' in history.columns:
        plt.plot(history['loss'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.title('Training Loss Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot penalty progression
plt.subplot(2, 2, 3)
for run_info in run_data:
    history = run_info['history']
    if 'penalty' in history.columns:
        plt.plot(history['penalty'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Penalty')
plt.title('Penalty Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot penalized reward vs base reward
plt.subplot(2, 2, 4)
for run_info in run_data:
    history = run_info['history']
    if 'penalized_reward' in history.columns and 'reward_mean' in history.columns:
        plt.plot(history['reward_mean'], label=f"{run_info['name']} (base)", alpha=0.7)
        plt.plot(history['penalized_reward'], label=f"{run_info['name']} (penalized)", alpha=0.7, linestyle='--')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Base vs Penalized Rewards')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Show summary statistics
print("\n=== Run Summary Statistics ===")
for run_info in run_data:
    print(f"\nRun: {run_info['name']}")
    summary = run_info['summary']
    config = run_info['config']
    
    # Show key metrics if available
    metrics_to_show = ['reward_mean', 'penalized_reward', 'penalty', 'loss']
    for metric in metrics_to_show:
        if metric in summary:
            print(f"  Final {metric}: {summary[metric]:.4f}")
    
    # Show key config parameters
    config_to_show = ['learning_rate', 'num_episodes', 'batch_size', 'penalty_per_word']
    for param in config_to_show:
        if param in config:
            print(f"  {param}: {config[param]}")
    
    # Show word penalties if configured
    if 'word_penalty' in config and config['word_penalty'].get('enabled'):
        words = config['word_penalty'].get('words', [])
        penalty_per_word = config['word_penalty'].get('penalty_per_word', 0)
        print(f"  Penalized words: {words} (penalty: {penalty_per_word})")

# %%
# Optional: Access run artifacts (like rollout data)
print("=== Available Artifacts ===")
for run_info in run_data:
    run = run_info['run']
    artifacts = run.logged_artifacts()
    
    if artifacts:
        print(f"\nRun {run_info['name']} has {len(artifacts)} artifacts:")
        for artifact in artifacts:
            print(f"  - {artifact.name} (type: {artifact.type}, size: {artifact.size})")
    else:
        print(f"\nRun {run_info['name']} has no artifacts")

# Example: Download and examine a rollout artifact (if available)
def examine_rollout_artifact(run_info):
    """Helper function to download and examine rollout data"""
    run = run_info['run']
    artifacts = run.logged_artifacts()
    
    rollout_artifacts = [a for a in artifacts if a.type == "dataset" and "rollouts" in a.name]
    
    if rollout_artifacts:
        print(f"\nDownloading rollout data for {run_info['name']}...")
        artifact = rollout_artifacts[0]  # Use the first rollout artifact
        artifact_dir = artifact.download()
        
        # Look for JSONL files in the artifact
        import os
        import json
        
        jsonl_files = [f for f in os.listdir(artifact_dir) if f.endswith('.jsonl')]
        if jsonl_files:
            jsonl_path = os.path.join(artifact_dir, jsonl_files[0])
            print(f"Found rollout file: {jsonl_path}")
            
            # Load first few rollouts as example
            rollouts = []
            with open(jsonl_path, 'r') as f:
                for i, line in enumerate(f):
                    if i >= 3:  # Only load first 3 for example
                        break
                    rollouts.append(json.loads(line))
            
            print(f"Loaded {len(rollouts)} example rollouts")
            if rollouts:
                print(f"Example rollout keys: {list(rollouts[0].keys())}")
                if 'rollout' in rollouts[0]:
                    print(f"Rollout data keys: {list(rollouts[0]['rollout'].keys())}")
            
            return rollouts
    return None

# Uncomment the following lines to download and examine rollout data:
# if run_data:
#     rollouts = examine_rollout_artifact(run_data[0])  # Examine first run's rollouts

# %%
SHOGGOTH_IDS = [
    "w4tt1jsu",
    "zfl5u3fd",
    "1sde8jph",
    "8fgq0wro",
    "w3euhlb8",
    ]

NO_PENALTY_IDS = [
    "9f3aqg2s",
    "x4ycjhu3",
    "tp2lfh4y",
    "1acq8chp",
    "put7hoex",
    "w6gsb6ok",
    "ip9tix4l",
    "5n394zv2",
]

PENALTY_IDS = [
    "zmhndno2",
    "sz2dldwu",
    "knaehdyp",
    "tty1nb3s",
    "z5f8wxgt",
    "eckpvxsz",
    "a11zhjue",
    "9wyk1cnx",
]

# %%
# Load detailed data for each acre run
run_data = []

for run in acre_runs:
    print(f"\nLoading data for run: {run.name}")
    
    # Get run configuration
    config = run.config
    
    # Get run summary (final metrics)
    summary = run.summary
    
    # Get run history (all logged metrics over time)
    history = run.history()
    
    # Store run information
    run_info = {
        'run': run,
        'name': run.name,
        'id': run.id,
        'state': run.state,
        'config': config,
        'summary': summary,
        'history': history
    }
    
    run_data.append(run_info)
    
    print(f"  - Config keys: {list(config.keys())}")
    print(f"  - Summary keys: {list(summary.keys())}")
    print(f"  - History shape: {history.shape}")
    print(f"  - History columns: {list(history.columns)}")

print(f"\nLoaded data for {len(run_data)} acre runs")

# %%
# Example: Plot training curves for all acre runs
plt.figure(figsize=(15, 10))

# Plot reward progression for each run
plt.subplot(2, 2, 1)
for run_info in run_data:
    history = run_info['history']
    if 'reward_mean' in history.columns:
        plt.plot(history['reward_mean'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Reward Mean')
plt.title('Training Reward Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot loss progression
plt.subplot(2, 2, 2)
for run_info in run_data:
    history = run_info['history']
    if 'loss' in history.columns:
        plt.plot(history['loss'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.title('Training Loss Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot penalty progression
plt.subplot(2, 2, 3)
for run_info in run_data:
    history = run_info['history']
    if 'penalty' in history.columns:
        plt.plot(history['penalty'], label=f"{run_info['name']}", alpha=0.7)
plt.xlabel('Episode')
plt.ylabel('Penalty')
plt.title('Penalty Progression')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot penalized reward vs base reward
plt.subplot(2, 2, 4)
for run_info in run_data:
    history = run_info['history']
    if 'penalized_reward' in history.columns and 'reward_mean' in history.columns:
        plt.plot(history['reward_mean'], label=f"{run_info['name']} (base)", alpha=0.7)
        plt.plot(history['penalized_reward'], label=f"{run_info['name']} (penalized)", alpha=0.7, linestyle='--')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Base vs Penalized Rewards')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Show summary statistics
print("\n=== Run Summary Statistics ===")
for run_info in run_data:
    print(f"\nRun: {run_info['name']}")
    summary = run_info['summary']
    config = run_info['config']
    
    # Show key metrics if available
    metrics_to_show = ['reward_mean', 'penalized_reward', 'penalty', 'loss']
    for metric in metrics_to_show:
        if metric in summary:
            print(f"  Final {metric}: {summary[metric]:.4f}")
    
    # Show key config parameters
    config_to_show = ['learning_rate', 'num_episodes', 'batch_size', 'penalty_per_word']
    for param in config_to_show:
        if param in config:
            print(f"  {param}: {config[param]}")
    
    # Show word penalties if configured
    if 'word_penalty' in config and config['word_penalty'].get('enabled'):
        words = config['word_penalty'].get('words', [])
        penalty_per_word = config['word_penalty'].get('penalty_per_word', 0)
        print(f"  Penalized words: {words} (penalty: {penalty_per_word})")

# %%
# Optional: Access run artifacts (like rollout data)
print("=== Available Artifacts ===")
for run_info in run_data:
    run = run_info['run']
    artifacts = run.logged_artifacts()
    
    if artifacts:
        print(f"\nRun {run_info['name']} has {len(artifacts)} artifacts:")
        for artifact in artifacts:
            print(f"  - {artifact.name} (type: {artifact.type}, size: {artifact.size})")
    else:
        print(f"\nRun {run_info['name']} has no artifacts")

# Example: Download and examine a rollout artifact (if available)
def examine_rollout_artifact(run_info):
    """Helper function to download and examine rollout data"""
    run = run_info['run']
    artifacts = run.logged_artifacts()
    
    rollout_artifacts = [a for a in artifacts if a.type == "dataset" and "rollouts" in a.name]
    
    if rollout_artifacts:
        print(f"\nDownloading rollout data for {run_info['name']}...")
        artifact = rollout_artifacts[0]  # Use the first rollout artifact
        artifact_dir = artifact.download()
        
        # Look for JSONL files in the artifact
        import os
        import json
        
        jsonl_files = [f for f in os.listdir(artifact_dir) if f.endswith('.jsonl')]
        if jsonl_files:
            jsonl_path = os.path.join(artifact_dir, jsonl_files[0])
            print(f"Found rollout file: {jsonl_path}")
            
            # Load first few rollouts as example
            rollouts = []
            with open(jsonl_path, 'r') as f:
                for i, line in enumerate(f):
                    if i >= 3:  # Only load first 3 for example
                        break
                    rollouts.append(json.loads(line))
            
            print(f"Loaded {len(rollouts)} example rollouts")
            if rollouts:
                print(f"Example rollout keys: {list(rollouts[0].keys())}")
                if 'rollout' in rollouts[0]:
                    print(f"Rollout data keys: {list(rollouts[0]['rollout'].keys())}")
            
            return rollouts
    return None

# Uncomment the following lines to download and examine rollout data:
# if run_data:
#     rollouts = examine_rollout_artifact(run_data[0])  # Examine first run's rollouts
